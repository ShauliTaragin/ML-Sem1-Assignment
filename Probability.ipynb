# %% [markdown]
# # Question $1a$

# %% [markdown]
# The probabilty For an identical twin is : $\dfrac{1}{300}$
#
# The probabilty For a non identical twin is : $\dfrac{1}{125}$
#
# We know that the boy/girl ratio is :50/50 therefore probabilty for a boy is : $\dfrac{1}{2}$
#
# Non identical twins can split into 4 cases - boy/boy , boy/girl , girl/girl , girl/boy.
#
# However We know elvis is a boy and had a boy twin brother cocluding a : $\dfrac{1}{4}$  chance .
#
# So the probabilty for a not identical boy twin is:  $\dfrac{1}{125} \cdot \dfrac{1}{4} $
#
#
# Identical twins can only be of the same sex , Therefore a $50\%$ chance for boy identical twins
#
# So the probabilty for an identical boy twin is:  $\dfrac{1}{300} \cdot \dfrac{1}{2} $
#
# Concluding the final equation to  be -
# the chance for an identical twin divided by the chance for an identical twin times  the chance for an unidentical twin
#
# Putting are words in to math we get-
# $\dfrac{\dfrac{1}{300}\cdot \dfrac{1}{2}}{\dfrac{1}{300}\cdot \dfrac{1}{2} + \dfrac{1}{125}\cdot \dfrac{1}{4}} =\dfrac{5}{11}$
#
# Bringing are final answer for the probabilty of elvis having an identical twin to $\dfrac{5}{11}$

# %% [markdown]
# # Question $1b$

# %% [markdown]
# The chance to pick each bowl of cookies is $ 50 \% $
#
# The chance of picking a chocolate cookie from the first bowl is :$\dfrac{30}{40} = \dfrac{3}{4} $
#
# The chance of picking a chocolate cookie from the second bowl is :$\dfrac{20}{40} = \dfrac{1}{2} $
#
# We know that eric grabbed a chocolate cookie we need to find the odds for eric picking out of the first bowl.
#
# To conclude the probabilty of picking from the first bowl is:
# $\dfrac{\dfrac{3}{4}\cdot \dfrac{1}{2}}{\dfrac{1}{2}\cdot \dfrac{1}{2} + \dfrac{1}{2}\cdot \dfrac{3}{4}} =\dfrac{3}{5}$
#
# Bringing are final answer for the probabilty of eric picking out of the first bowl to $\dfrac{3}{5}$

# %% [markdown]
# # Question $2$

# %% [markdown]
# The hypothesis we have is:
#
# A: Bag $1$ is from $1994$ and Bag $2$ is from $1996$
#
# B: Bag $2$ is from $1994$ and Bag $1$ is from $1996$
#
# We can easily see that the probability for each case(A , B ) is $ 50\% $
#
# The evidence we have is:
#
# Yellow from bag 1(the 1994 bag) and green from bag 2 (the 1996 bag).
#
# Since the probability of taking a yellow from 1994 is intertwined with taking a green from 1996 we(and vice versa for yellow from 1996) we have to multiply the probabilty.
#
# So the probabilty for a yellow  m&m from bag 1 is :
# $(0.2)\cdot(0.2) = 0.04$
#
# and the probabilty for a yellow  m&m from bag 2 is :
# $(0.1)\cdot(0.14) = $
#
# Plugging that into the bayes probabilty theorem we get:
#
# P(A | B) = $\dfrac{P(A and B)}{ P(B)} = \dfrac{0.04}{0.2 \cdot 0.2 + 0.1 \cdot 0.14} = \dfrac{0.04}{0.054} = 0.74074 $

# %% [markdown]
# # Question $3a$

# %% [markdown]
# This a classic bayes theorem question therefore we will write the evidence and hypothesis:
#
# H= You are actually sick
#
# E= You tested positive for swine flu
#
# We need to find what is the probability of you having swine flu which is: P(H | E)
#
# P(H) = $ \dfrac{1}{10000}$
#
# P(E) = $ \dfrac{1}{10000} + \dfrac{9999}{10000} \cdot \dfrac{1}{100} $
#
# P(E|H) = $1$
#
# plugging that all into the Bayes fromula we get :
#
# P(H|E) = $\frac{P(E|H) \cdot P(H)}{P(E)} = \frac{1 \cdot \dfrac{1}{10000}}{\dfrac{1}{10000} + \dfrac{9999}{10000} \cdot \dfrac{1}{100}} = \dfrac{100}{10099}  $

# %% [markdown]
# # Question $3b$

# %% [markdown]
# Similarly to section a :
#
# H= You are actually sick(with new Thailand data)
#
# E= You tested positive for swine flu
#
# We need to find what is the probability of you having swine flu which is: P(H | E)
#
# P(H) = $ \dfrac{1}{200}$
#
# P(E) = $ \dfrac{1}{200} + \dfrac{199}{200} \cdot \dfrac{1}{100} $
#
# P(E|H) = $1$
#
# plugging that all into the Bayes fromula we get :
#
# P(H|E) = $\frac{P(E|H) \cdot P(H)}{P(E)} = \frac{1 \cdot \dfrac{1}{10000}}{\dfrac{1}{200} + \dfrac{199}{200} \cdot \dfrac{1}{100}} = \dfrac{100}{299} = 0.3344 \%  $

# %% [markdown]
# # Random Variables

# %% [markdown]
# # Question $1$

# %% [markdown]
# Rolling two dice gives us 36 options of an outcome .
#
# A = For roey to roll a number that divides 3 there are 12 options out of 36.
#
# B = For roey to roll a number that dosen't divide 3 there are 24 options out of 36.
#
# P(A) = $\dfrac{1}{3}$ (if this happens Roey wins 6$)
#
# P(B) = $\dfrac{2}{3}$ (if this happens Roey loses 3$)
#
# So the expected value is :
#
# $(\dfrac{1}{3} \cdot 6 ) +(\dfrac{2}{3} \cdot (-3)) =0 $

# %% [markdown]
# # Question $2$

# %% [markdown]
# Playing marker mixup gives us 25 options of an outcome ($5\cdot 5\ = 25$) .
#
# Break even = The amount of options for Alex to pick 2 markres for which the sum of them is equel to 12 is -  4.
#
# Lose = The amount of options for Alex to pick 2 markres for which the sum of them is less then 12 is -  15.
#
# Win = The amount of options for Alex to pick 2 markres for which the sum of them is equel to 12 is -  6.
#
# P(Break Even) = $\dfrac{4}{25}$ (if this happens Alex wins 0$)
#
# P(Lose) = $\dfrac{15}{25}$ (if this happens Alex loses 6$)
#
# P(Win) = $\dfrac{6}{25}$ (if this happens Alex wins 5$)
#
# So the expected value is :
#
# $(\dfrac{4}{25} \cdot 0 ) +(\dfrac{15}{25} \cdot (-6)) +(\dfrac{6}{25} \cdot (5)) = -2.4 $
#
# (Alex should not play)

# %% [markdown]
# # Question $3$

# %% [markdown]
# The company has 200 empolyes.
#
# Men empolyes are 40% of the companies employees  therefore - 80 employes.
#
# Women empolyes are 60% of the companies employees  therefore - 120 employes.

# %% [markdown]
# # Question $4$

# %% [markdown]
# We know the mean is 26,000 or 26 in our case, and the std is 2,000 or 2 in our case.
#
# By the 68-95-99.7 rule
#
# ![image.png](attachment:image.png)
#
# $\mu$ being the mean.
#
# $\sigma$ being the std.
#
# a. So we know that if we add to the mean 1 std we get approximately  34% percent of the results ($\mu$ + $\sigma$)
#
# b. If we add to the mean 2 std we get approximately  14% percent of the results ($\mu + 2\sigma$)
#
# Since we know std is 2 and we want to find the 26<P(X)<30 , we need to combine a and b to find the result.
#
# Therefore:
#
# $P(X) = 14\% + 34\% = 48\% $
